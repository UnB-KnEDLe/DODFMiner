# %%
# Renomeie o arquivo para out_teste_file

# %%
# !apt-get install tesseract-ocr imagemagick poppler-utils libtesseract-dev

# %%
# !pip install pytesseract

# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os
import time

# %%
# Rodar uma só vez para ter permissão de usar o convert
# !sudo mv /etc/ImageMagick-6/policy.xml /etc/ImageMagick-6/policy.xmlout

# %%
inicio = time.time()
# !convert -density 300 teste_file.pdf -depth 1 -strip -background white -alpha off out_teste_file.png
fim = time.time()
print(fim - inicio)
# Out:
#    **** Error: /BBox has zero width or height, which is not allowed.
#                Output may be incorrect.
# 21.273343324661255

# %%
inicio = time.time()
# !pdftoppm teste_file.pdf out_teste_toppm -png
fim = time.time()
print(fim - inicio)
# Out:
# I/O Error: Couldn't open file 'teste_file.pdf': No such file or directory.
# 3.118731737136841

# %%
# Rodar só caso de erro no diretorio do tesseract uma vez para apontar o path do pytesseract
# pytesseract.pytesseract.tesseract_cmd = '/usr/local/bin/pytesseract'

# %%
# !tesseract -v
# Out:
# tesseract 4.0.0-beta.1
#  leptonica-1.75.3
#   libgif 5.1.4 : libjpeg 8d (libjpeg-turbo 1.5.2) : libpng 1.6.34 : libtiff 4.0.9 : zlib 1.2.11 : libwebp 0.6.1 : libopenjp2 2.3.0
#
#  Found AVX512BW
#  Found AVX512F
#  Found AVX2
#  Found AVX
#  Found SSE

# %%
# Teste com toppm
# O convert cria uma imagem para cada pag do pdf
inicio = time.time()
image_1 = Image.open('out_teste_toppm-1.png')
pag1_text = pytesseract.image_to_string(image_1, lang='por')
print(pag1_text)
fim = time.time()
print(fim - inicio)
# Out:
# & DIARIO OFICIAL
#
# DISTRITO
#
# FEDERAL
#
#
#
# ANO XLVIXx +S EXTRA N®* 10
#
# BRASILIA - DF, TERGA-FEIRA, 4 DE FEVEREIRO DE 2020
#
#
#
# SUMARIO
#
#
#
# Poder Executivo 9
#
# Secretaria de Estado de Educacao 1
# SECAO |
# SECRETARIA DE ESTADO DE EDUCACAO
#
# PORTARIA N° 19, DE 3 DE FEVEREIRO DE 2020
# Dispde sobre os procedimentos necessirios para contratag3o de servicos de pequeno valor nas unidades de
# ensino da rede publica com recursos oriundos do Programa de Descentralizagao Financeira- PDAF, conforme
# estabelecido na Portaria Conjunta SDE/SEE/CPPGE n° 07, de 16 de setembro de 2019, que institui o Programa
# Pequenos Reparos
# O SECRETARIO DE ESTADO DE EDUCAGAO DO DISTRITO FEDERAL, no uso das atribuigdes
# previstas nos incisos III e V, do Paragrafo tinico, do Art. 105, da Lei Organica do Distrito Federal, e no Art.
# 182, Incisos Ve X do Regimento Interno da Secretaria de Estado de Educacao do Distrito Federal, aprovado
# pelo Decreto n° 38.631 de 20 de novembro de 2017,
# CONSIDERANDO a Lei Distrital n° 6.023, de 18 de dezembro de 2017, que institui o Programa de
# Descentralizagiio Administrativa e Financeira - PDAF e dispde sobre sua aplicagdo e execugao nas unidades
# escolares e nas Coordenagdes Regionais de Ensino da Rede Pablica de Ensino do Distrito Federal;
# CONSIDERANDO a Lei n° 4.751, de 07 de fevereiro de 2012, que dispde sobre o Sistema de Ensino e a
# Gestdo Demoeritica do Sistema de Ensino Publico do Distrito Federal;
# CONSIDERANDO a Portaria Conjunta SDE/SEE/CPPGE n° 07, de 16 de setembro de 2019, que estabelece 0
# Programa Pequenos Reparos como modal preferencial para contratacao dos pequenos servigos que especifica
# para as escolas piiblicas da Secretaria de Estado de Educagio do Distrito Federal - SEE/DF, favorecendo 0
# acesso 4 contratagio de Microempreendedores Individuals previamente habilitados e credenciados pela
# Secretaria de Estado de Desenvolvimento Econémico-SDE/DF, resolve:
# Art. 1° Estabelece os procedimentos necessarios para a realizagao de servigos de pequeno valor nas unidades
# escolares e nos prédios pertencentes as unidades escolares da rede publica de ensino, com recursos oriundos do
# Programa de Descentralizagio Financeira- PDAF.
# Art. 2° Esta Portaria entra em vigor na data de sua publicagio.
#
# JOAO PEDRO FERRAZ DOS PASSOS
#
#
#
# ANEXO UNICO
# PROCEDIMENTOS PARA CONTRATACAO DE SERVICOS DE PEQUENO NAS UNIDADES DE
# ENSINO DA REDE PUBLICA
# Capitulo I
# Disposigdes Gerais
# Art. 1° Os pequenos reparos sao servigos de reforma de pequeno valor, em que no ha alteragio de rea
# construida, passiveis de serem executados por profissional, Microempreendedor Individual- MEI, com
# cadastro de pessoa juridica e escrituragdo contabil regular.
# Art. 2° Os servicos de pequenos reparos poderio ser executados pelos profissionais listados no §1°, do art. 1°,
# da Portaria Conjunta SDE/SEE/CPPGE n? 07, de 16 de setembro de 2019, quais sejam:
# 1 - Bombeiro hidriulico.
# IL - Chaveiro.
# IIL - Eletricista.
# IV -Jardineiro.
# V - Pedreiro.
# VI- Pintor,
# VII - Serralheiro.
# VIII -Técnico em Informatica e
# IX - Técnico em eletroeletrdnica.
# Art. 3° Os recursos provenientes da utilizagdo dos servigos de que trata esta Portaria serdo do Programa de
# Descentralizagdo Administrativa e Financeira - PDAF, instituido pela Lei n° 6.023, de 18 de dezembro de
# 2017.
#
# Art. 4° Os servigos de pequenos reparos de que trata este expediente sero realizados, preferencialmente, pelos
# microempreendedores individuais previamente cadastrados no Banco de Credenciados criado pela Secretaria
# de Desenvolvimento Econdmico do Distrito Federal - SDE para esse fim.
#
# Art. 5° As Unidades Executoras - UExL deverio atentar estritamente aos limites de servigos considerados
# pequenos reparos de eletricista, bombeiro hidriulico, pintor, pedreiro, chaveiro, jardineiro, serralheiro, técnico
# em informatica e técnico de eletroeletrénicos estabelecidos nesta Portaria.
#
# Art. 6° Sio consideradas Unidades Executoras - UEXL as organizagdes da sociedade civil com personalidade
# juridica de direito privado, sem fins lucrativos, instituidas por iniciativa da unidade escolar, ou da Coordenagao
# Regional de Ensino, da comunidade escolar ou de ambas, nos termos da Lei n° 6.023, de 18 de dezembro de
# 2017.
#
# §1° UEXL: sociedade civil com personalidade juridica de direito privado, sem fins lucrativos, que deve ser
# instituida por iniciativa da escola, da comunidade escolar ou de ambas, sob a forma de Associacao de Pais ¢
# Mestres - APM, Associagio de Pais, Alunos e Mestres - APAM, Caixas Escolares-CxE ou outras
# denominagdes, com a finalidade de apoiar e promover iniciativas com vistas 4 melhoria da qualidade do
# processo educativo;
#
# § 2° UEXR: sob a forma de Associagio de Apoio a Educagiio, no Ambito da respectiva regional de ensino, com
# a finalidade estatutéria de apoiar e promover iniciativas com vistas 4 melhoria da qualidade do proceso
# educativo,
#
#
#
# Capitulo I
#
# Dos tipos de servigos
# Art. 7° Os pequenos reparos, objeto desta Portaria classificam-se em dois tipos, a saber:
# 1- Tipo I.
# I1- Tipo Il.
# Il - Tipo IIL.
# Art. 8° Os servigos de pequenos reparos tipo I poderdo ser realizados pela Unidade Executora, sem anuéneia
# prévia da equipe técnica da Subsecretaria de Infraestrutura e Apoio Educacional - SIAE.
# Art. 9° Os servigos de pequenos reparos tipo II poderio ser realizadaos pela UexL, contudo, necessitardio de
# anuéncia prévia da equipe técnica da SIAE.
# Art. 10 Os servigos pequenos reparos tipo III, ndo poderio ser realizados pela UEXL, inicialmente, pois
# necessitardo de avaliagio técnica da Diretoria de Engenharia - DIRED/ Geréncia de Manutengio da Unidades
# Escolares - GMESC, devidamente validado pela SIAE.
# Art, 1] Para enquadramento dos reparos abrangidos nos artigos anteriores a UExL devera consultar a Cartilha
# de Conservagao dos prédios piblicos pertencentes 4 rede piblica de ensino do Distrito Federal, elaborada pela
# equipe técnica da SIAE.
# Parigrafo unico. A Cartilha de Conservagao dos prédios foi publicada no sitio eletrénico da SEEDF, no dia
# 30/01/2020, em formato PDF, para consulta piiblica.
# Capitulo 11
# Dos procedimentos para execugio dos servigos
# Art. 12 Em caso de necessidade de realizago de pequenos reparos dos tipos II ¢ III, a UExL devera notificar
# a DIRED, que ter o prazo de 30 dias para aprovar o servigo.
# §1° O prazo referido no caput deste artigo poder ser prorrogado mediante justificativa técnica da DIRED,
# enderegada ao titular da SIAE, que deverd relatar os motivos da impossibilidade de aprovagdo do servigo
# requerido pela UExL no prazo exigido, cabendo a este deliberar sobre a prorrogacao.
# §2° A aprovacdo devera ser formalizada em documento escrito, devidamente assinado pelos profissionais da
# DIRED que realizaram a vistoria técnica,
# §3° Caso 0 servigo de pequenos reparos dos tipos II ou III, nao sejam aprovado, a equipe técnica da DIRED
# deverd elaborar relatério técnico informando os motivos da reprovagiio, bem como as agdes necessirias para
# regularizaco da situag3o apresentada na unidade escolar.
# §°4 0 responsive pela UEXL que realizar reparos do tipo II ou tipo III, sem prévia consulta ao corpo técnico
# da DIRED, validada pela SAE, responder pelos danos, conforme preconiza a legislago especifica,
# Capitulo IV
# Do Banco de Credenciados
# Art. 13 As UEXL deverio solicitar a Secretaria de Estado de Desenvolvimento Econémico - SDE, por meio de
# Oficio via Sistema Eletrénico de Informagdo, a indicagio dos profissionais do Banco de Credenciados que
# fardo os orgamentos, para cada tipo de pequeno reparo,
# § 1° Para ser indicado, 0 MEI devera estar previamente habilitado ¢ integrado ao Banco de Credenciados no(s)
# servigo(s) a que se propde atender, estando submetido a rigorosa ordem cronolégica de inclusio, a0 rodizio
# automatico e aos sucessivos reposicionamentos ao final da lista de rodizio, apos a prestagdo de servigo de
# forma exitosa.
# § 2° A SDE informara os MEIs ocupantes das 3 (trés) primeiras posigdes do Banco de Credenciados 4 UExL,
# para cada servi¢o requerido.
# § 3° Os selecionados sero contatados e cientificados pela UExL quanto a necessidade de atendimento a
# demanda, da localizagao e da obrigatoriedade de fornecimento de orgamento, no prazo de até 3 (trés) dias
# liteis;
# § 4° Caso nio seja atendido o prazo indicado no §3°, poder a Unidade Executora proceder 0 chamamento do
# proximo na lista, até o limite de 3 (trés) orgamentos, aps registro da auséncia de resposta no cadastro do
# credenciado faltoso no Banco de Credenciados;
# § 5° Caso a UEXL entenda pela ndo vantajosidade 4 Administragdo Pablica dos orgamentos apresentados pelos
# credenciados, poder solicitar a indicagio de 3 (trés) novos credenciados, de forma fundamentada, remetendo
# ao Gabinete da SEEDF os orgamentos nao acolhidos, para acompanhamento e providéncias que julgar
# necessirias junto 4 SDE.
# § 6° O MEI contratado, ao final do servigo e cumpridos os indicadores de qualidade, retornara ao Banco de
# Credenciados em tltimo lugar, garantindo o rodizio,
# Art. 14, A UEXL devera optar, atendido ao interesse piblico, pelo orgamento que indique o menor niimero de
# horas técnicas de para a execugo do pequeno reparo, considerando que os servigos serio pagos por hora, em
# homenagem ao principio da economicidade.
# Art. 15. A UEXL serd responsivel por providenciar, em tempo habil, a compra do material necessirio para a
# execugdo dos servigos contratados, excluidos equipamentos ¢ maquinario necessirios 4 execucdo do servigo.
# Parigrafo inico. A UExL devera observar os procedimentos objetivos e simplificados para aquisigiio de
# materiais e produtos, adequados  natureza da despesa, nos termos do art. 18 da Lei n° 6.023, de 18 de
# dezembro de 2017.
# Art. 16. A UExL devera informar 4 SDE e sobre a formalizagao do Contrato ¢ consequente devolucao dos
# demais proponentes.
# Art. 17, Apos a realizagdo do servigo ¢ o encerramento do contrato, a UExL deverd avaliar 0 servigo
# contratado, preenchendo 0 formulario de indicador de qualidade a ser fornecido pela SDE.
# Art. 18, A UEXL devera fixar na Coordenagiio Regional de Ensino ou Unidade Escolar, em local de acesso
# piblico, informagdes sobre 0 modelo de credenciamento, bem como a cartilha de manutengio dos prédios
# pablicos pertencentes a rede piibliea de ensino.
# Art. 19. E vedado a UEXL utilizar 0 acesso ao Banco de Credenciados ou ceder dados pessoais dos cadastrados
# para fim diverso do atendimento as demandas da unidade, sob pena de responsabilidad.
# Parigrafo tnico. Aplica-se 0 disposto no caput deste artigo a todos os que tiverem acesso ao Banco de
# Credenciad
# Art, 20. Caso nao seja po:
# exemplo profissional di
# prestacdo do servigo, pi
# Banco de Credenciados.
# §1° Na hipétese citada no pardgrafo anterior, & necessdria, mediante justificativa escrita e fundamentada, a
# demonstragio da gravidade e da urgéncia do servigo, bem como a comprovagio de que foi solicitado o
# orgamento a, pelo menos, trés fornecedores credenciados, e que nao foi possivel a prestagio do servigo por
# meio do Programa,
#
#
#
#
#
#
#
# possivel a contratacdo de MEI do Banco de Credenciados, na hipétese de no haver por
# onivel para a realizagio do servigo, em virtude da urgéncia e necessidade da
# jer a UEXL contratar pequenos servigos de outros profissionais no inseridos no
#
#
#
#
#
#
#
# Este documento pode ser
# pelo cédigo 50102020020400001
#
# verificado no enderego eletrdnico _http:/www.in.gov.br/autenticidade html,
#
# Documento assinado digitalmente conforme MP n° 2.200-2 de 24/08/2001, que institui a
# Infraestrutura de Chaves Publicas Brasileira - ICP-Brasil.
# 26.192538738250732

# %%
# O convert cria uma imagem para cada pag do pdf
inicio = time.time()
image_0 = Image.open('out_teste_file-0.png')
pag0_text = pytesseract.image_to_string(image_0)
print(pag0_text)
fim = time.time()
print(fim - inicio)
# Out:
# 4
#
#
#
# GOVERNO 00 ana FEDERAL S
# ANO XLVIX ce EXTRA N® 10
#
# SUMARIO
#
# SEGAO I SECAO II
# PAG. PAG.
# Poder Executivo ........ccccccccecscsssessessesseeseeseceseeaeeaecaesseeeaseaecaeeeeeeaeeesseeeates . 9
# Secretaria de Estado de Educaco .0.......ccccccceceseeeseseesseeneeeeesseeneeneeeee . 1
#
# SECAO |
# SECRETARIA DE ESTADO DE EDUCAGAO
#
# PORTARIA N° 19, DE 3 DE FEVEREIRO DE 2020
# Dispéc sobre os procedimentos necessarios para contratacgéo de servicgos de pequeno valor nas unidades de
# ensino da rede publica com recursos oriundos do Programa de Descentralizagao Financcira- PDAF, conforme
# estabelecido na Portaria Conjunta SDE/SEE/CPPGE n° 07, de 16 de sctembro de 2019, que institui o Programa
# Pequenos Reparos.
# O SECRETARIO DE ESTADO DE EDUCACAO DO DISTRITO FEDERAL, no uso das atribuigécs
# previstas nos incisos III ¢ V, do Paragrafo unico, do Art. 105, da Lei Organica do Distrito Federal, ¢ no Art.
# 182, Incisos V ec X do Regimento Interno da Scerctaria de Estado de Educacao do Distrito Federal, aprovado
# pelo Decreto n° 38.631 de 20 de novembro de 2017,
# CONSIDERANDO a Lei Distrital n° 6.023, de 18 de dezembro de 2017, que institui o Programa de
# Descentralizagéo Administrativa c Financcira - PDAF ¢ dispdc sobre sua aplicagéo c execucéo nas unidades
# escolares ¢ nas Coordenacdes Regionais de Ensino da Rede Publica de Ensino do Distrito Federal;
# CONSIDERANDO a Lei n° 4.751, de 07 de feverciro de 2012, que dispde sobre o Sistema de Ensino ¢ a
# Gestéo Democratica do Sistema de Ensino Publico do Distrito Federal;
# CONSIDERANDO a Portaria Conjunta SDE/SEE/CPPGE n° 07, de 16 de sctembro de 2019, que estabelece o
# Programa Pequenos Reparos como modal preferencial para contratagao dos pequenos servicos que especifica
# para as cscolas ptiblicas da Secretaria de Estado de Educacao do Distrito Federal - SEE/DF, favorecendo o
# acesso a contratagéo de Microcmpreendedores Individuais previamente habilitados ¢ credenciados pela
# Secretaria de Estado de Desenvolvimento Econémico-SDE/DF, resolve:
# Art. 1° Estabelece os procedimentos necessarios para a realizacao de servigos de pequeno valor nas unidades
# escolares ¢ nos prédios pertencentes as unidades escolares da rede publica de ensino, com recursos oriundos do
# Programa de Descentralizacéo Financeira- PDAF.
# Art. 2° Esta Portaria entra em vigor na data de sua publicagao.
#
# JOAO PEDRO FERRAZ DOS PASSOS
#
# ANEXO UNICO
# PROCEDIMENTOS PARA CONTRATACAO DE SERVICOS DE PEQUENO NAS UNIDADES DE
# ENSINO DA REDE PUBLICA
# Capitulo I
# Disposi¢ées Gerais
# Art. 1° Os pequenos reparos séo servicos de reforma de pequeno valor, em que nao ha alteracéo de arca
# construida, passiveis de serem cxeccutados por profissional, Microcmpreendedor Individual- MEI, com
# cadastro de pessoa juridica ¢ escrituracao contabil regular.
# Art. 2° Os servigos de pequenos reparos poderao scr cxecutados pclos profissionais listados no $1°, do art. 1°,
# da Portaria Conjunta SDE/SEE/CPPGE n° 07, de 16 de sctembro de 2019, quais scjam:
# 1 - Bombeiro hidraulico.
# II - Chaveiro.
# IL - Elctricista.
# IV -Jardinciro.
# V - Pedreiro.
# VI - Pintor.
# VII - Serralheiro.
# VUI -Técnico cm Informatica ¢
# IX - Técnico cm elctrocletrénica.
# Art. 3° Os recursos provenicntes da utilizagdo dos scrvicos de que trata csta Portaria scrao do Programa de
# Descentralizagaéo Administrativa c Financcira - PDAF, instituido pela Lei n° 6.023, de 18 de dezembro de
# 2017.
# Art. 4° Os servigos de pequenos reparos de que trata cste expedicnte scrao realizados, preferencialmente, pelos
# microcmpreendedores individuais previamente cadastrados no Banco de Credenciados criado pela Secretaria
# de Desenvolvimento Econémico do Distrito Federal - SDE para esse fim.
# Art. 5° As Unidades Exccutoras - UExL deverao atentar cstritamente aos limites de servigos considcrados
# pequenos reparos de elctricista, bombciro hidraulico, pintor, pedreiro, chaveiro, jardinciro, scrralhciro, técnico
# em informatica e técnico de cletroeletrénicos estabclecidos nesta Portaria.
# Art. 6° Sao consideradas Unidades Exccutoras - UExL as organizacées da socicdade civil com personalidade
# juridica de dircito privado, scm fins lucrativos, instituidas por iniciativa da unidade escolar, ou da Coordenagao
# Regional de Ensino, da comunidade escolar ou de ambas, nos termos da Lei n° 6.023, de 18 de dezembro de
# 2017.
# $1° UEXL: sociedade civil com personalidade juridica de dircito privado, sem fins lucrativos, que deve ser
# instituida por iniciativa da escola, da comunidade escolar ou de ambas, sob a forma de Associacao de Pais ¢
# Mestres - APM, Associacéo de Pais, Alunos ec Mestres - APAM, Caixas Escolares-CxE ou outras
# denominagécs, com a finalidade de apoiar e promover iniciativas com vistas 4 melhoria da qualidade do
# processo educativo;
# § 2° UExR: sob a forma de Associacéo de Apoio a Educacao, no 4mbito da respectiva regional de ensino, com
# a finalidade cstatutaria de apoiar ¢ promover iniciativas com vistas 4 mclhoria da qualidade do processo
# educativo.
# Capitulo I
#
# a DIARIO OFICIAL
#
# FE D ER AOL
#
# BRASILIA - DF, TERCA-FEIRA, 4 DE FEVEREIRO DE 2020
#
# Dos tipos de servicos
# Art. 7° Os pequenos reparos, objeto desta Portaria classificam-sc cm dois tipos, a saber:
# 1- Tipo I.
# IL - Tipo I.
# III - Tipo II.
# Art. 8° Os servicos de pequenos reparos tipo I poderao ser realizados pela Unidade Exccutora, sem anuéncia
# prévia da cquipe técnica da Subsecretaria de Infracstrutura e Apoio Educacional - SIAE.
# Art. 9° Os servigos de pequenos reparos tipo II podcerao ser realizadaos pela UcxL, contudo, necessitaraéo de
# anuéncia prévia da equipe técnica da SIAE.
# Art. 10 Os servigos pequenos reparos tipo II, nao poderao ser realizados pela UEXL, inicialmente, pois
# necessitarao de avaliacao técnica da Diretoria de Engenharia - DIRED/ Geréncia de Manuten¢ao da Unidades
# Escolares - GMESC, devidamente validado pela SIAE.
# Art. 11 Para enquadramento dos reparos abrangidos nos artigos anteriores a UExL devera consultar a Cartilha
# de Conscrvagao dos prédios plblicos pertencentes a rede publica de ensino do Distrito Federal, claborada pela
# equipe técnica da SIAE.
# Paragrafo unico. A Cartilha de Conscrvagao dos prédios foi publicada no sitio cletrénico da SEEDF, no dia
# 30/01/2020, em formato PDF, para consulta publica.
# Capitulo HI
# Dos procedimentos para execucao dos servicos
# Art. 12 Em caso de necessidade de realizagao de pequenos reparos dos tipos II ¢ III, a UExL devera notificar
# a DIRED, que tera o prazo de 30 dias para aprovar o scrvigo.
# $1° O prazo referido no caput deste artigo podera ser prorrogado mediante justificativa técnica da DIRED,
# enderecada ao titular da SIAE, que devera relatar os motivos da impossibilidade de aprovacaéo do servi¢o
# requcrido pela UEXL no prazo cxigido, cabendo a este deliberar sobre a prorrogac¢ao.
# §2° A aprovacao devera scr formalizada cm documento escrito, devidamente assinado pclos profissionais da
# DIRED que realizaram a vistoria técnica.
# §3° Caso o servico de pequenos reparos dos tipos II ou III, nao scjam aprovado, a cquipe técnica da DIRED
# devera claborar relatério técnico informando os motivos da reprovagéo, bem como as agéecs necessarias para
# regularizacaéo da situagaéo apresentada na unidade escolar.
# §°4 O responsavel pela UEXL que realizar reparos do tipo II ou tipo IIL sem prévia consulta ao corpo técnico
# da DIRED, validada pela SIAE, respondera pelos danos, conforme preconiza a legislacao cspecifica.
# Capitulo [IV
# Do Banco de Credenciados
# Art. 13 As UExL deverao solicitar 4 Secretaria de Estado de Desenvolvimento Econémico - SDE, por meio de
# Oficio via Sistema Elctrénico de Informagao, a indicagaéo dos profissionais do Banco de Credenciados que
# faréo os orcamentos, para cada tipo de pequeno reparo.
# § 1° Para ser indicado, o MEI devera estar previamente habilitado c integrado ao Banco de Credenciados no(s)
# scrvico(s) a que se propdc atender, cstando submcetido a rigorosa ordem cronolégica de inclusao, ao rodizio
# automatico ¢ aos succssivos reposicionamentos ao final da lista de rodizio, apds a prestacao de servico de
# forma ecxitosa.
# § 2° A SDE informara os MElIs ocupantes das 3 (trés) primciras posigécs do Banco de Credenciados 4 UExL,
# para cada scrvico requerido.
# § 3° Os sclecionados scrao contatados ¢ cientificados pela UExL quanto a necessidade de atendimento a
# demanda, da localizagéo ¢ da obrigatoricdade de fornecimento de orgamento, no prazo de até 3 (trés) dias
# liteis;
# § 4° Caso nao scja atendido o prazo indicado no §3°, podera a Unidade Exccutora proceder o chamamento do
# proximo na lista, até o limite de 3 (trés) orgamentos, apds registro da auséncia de resposta no cadastro do
# credenciado faltoso no Banco de Credenciados;
# § 5° Caso a UEXL entenda pela nao vantajosidade 4 Administragéo Publica dos orgamentos apresentados pelos
# credenciados, podera solicitar a indicacéo de 3 (trés) novos credenciados, de forma fundamentada, remetendo
# ao Gabinete da SEEDF os orgamentos nao acolhidos, para acompanhamento ¢ providéncias que julgar
# necessarias junto 4 SDE.
# § 6° O MEI contratado, ao final do servi¢o ¢ cumpridos os indicadores de qualidade, retornara ao Banco de
# Credenciados cm ultimo lugar, garantindo o rodizio.
# Art. 14. A UExL devera optar, atendido ao interesse publico, pelo orgamento que indique o menor numero de
# horas técnicas de para a execucao do pequeno reparo, considcrando que os servi¢os scréo pagos por hora, em
# homenagem ao principio da cconomicidade.
# Art. 15. A UExL scra responsavel por providenciar, em tempo habil, a compra do material necessario para a
# exccuc¢ao dos servicos contratados, cxcluidos cquipamentos e maquinario necessarios a cxecucao do servi¢go.
# Paragrafo unico. A UExL devera observar os procedimentos objctivos ¢ simplificados para aquisigaéo de
# matcriais ¢ produtos, adequados a4 natureza da despesa, nos termos do art. 18 da Lei n° 6.023, de 18 de
# dezembro de 2017.
# Art. 16. A UExL devera informar 4 SDE ¢ sobre a formalizacéo do Contrato e¢ consequente devolucao dos
# demais proponcntes.
# Art. 17. Apdos a realizagao do servi¢o ¢ o encerramento do contrato, a UExL devera avaliar o servi¢o
# contratado, preenchendo o formulario de indicador de qualidade a ser fornecido pela SDE.
# Art. 18. A UEXxL devera fixar na Coordenacaéo Regional de Ensino ou Unidade Escolar, em local de accesso
# publico, informacées sobre o modelo de credenciamento, bem como a cartilha de manutengao dos prédios
# publicos pertencentes a rede publica de cnsino.
# Art. 19. E vedado a UEXL utilizar o acesso ao Banco de Credenciados ou ceder dados pessoais dos cadastrados
# para fim diverso do atendimento as demandas da unidade, sob pena de responsabilidade.
# Paragrafo tinico. Aplica-se o disposto no caput deste artigo a todos os que tiverem accesso ao Banco de
# Credenciados.
# Art. 20. Caso nao scja possivel a contratacao de MEI do Banco de Credenciados, na hipétese de nao haver por
# exemplo profissional disponivel para a realizagéo do secrvig¢o, em virtude da urgéncia ¢ necessidade da
# prestacgado do servico, podera a UExL contratar pequenos servigos de outros profissionais nao inscridos no
# Banco de Credenciados.
# $1° Na hipétese citada no paragrafo anterior, é necessaria, mediante justificativa cscrita c fundamentada, a
# demonstragéo da gravidade c da urgéncia do servico, bem como a comprovacgaéo de que foi solicitado o
# orcamento a, pelo menos, trés fornecedores credenciados, ¢ que nao foi possivel a prestacao do servico por
# meio do Programa.
#
#
#
# Este documento pode ser verificado no
#
# pelo cddigo 50102020020400001
#
# enderego eletrénico —_http:/Avww.in.gov.br/autenticidade.html,
#
# Documento assinado digitalmente conforme MP n° 2.200-2 de 24/08/2001, que institui a
# Infraestrutura de Chaves Publicas Brasileira - ICP-Brasil.
# 39.78604769706726

# %%
image_5 = Image.open('out_teste_file-5.png')
pag5_text = pytesseract.image_to_string(image_5)
print(pag5_text)
# Out:
# PAGINA 6
#
# Diario Oficial do Distrito Federal - Edicao Extra
#
# N° 10, terca-feira, 4 de fevereiro de 2020
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 97 EC 26 DE CEILANDIA RS 23.855,00 171 EC 21 DO GAMA R$ 18.255,00
# 98 EC 27 DE CEILANDIA R$ 26.165,00 172 EC 22 DO GAMA R$ 31.160,00
# 99 EC 28 DE CEILANDIA R$ 31.870,00 44 Ee 3 Ke CANA Re aa Ay
# 100 EC 29 DE CEILANDIA R$ 21.805,00 175 EC CORREGO BARREIRO RS 8.938,75
# 101 EC 31 DE CEILANDIA R$ _45.825,00 176 EC PONTE ALTA DE CIMA R$ 9.608,00
# 102 EC 33 DE CEILANDIA RS 46.480,00 177 JL 02 DO GAMA RS 19.440,00
# 103 EC 34 DE CEILANDIA R$ 45.130,00 145 h a bo IRVIN Re 17 eon
# 104 EC 35 DE CEILANDIA RS 52.450,00 i909” 103 DO GAMA Re 1430800
# 105 EC 36 DE CEILANDIA R$ 40.030,00 181 Tl 06 DO GAMA RS 15.255.00
# 106 EC 38 DE CEILANDIA RS 55.690,00 182 CRE GUARA RS 230.000,00
# 107 EC 39 DE CEILANDIA R$ 38.635,00 183 CED 01 DA ESTRUTURAL R$ _109.183,00
# 108 EC 40 DE CEILANDIA R$ 53.053,00 Ta CED On Ke ev aR Re op ase a
# 109 EC 43 DE CEILANDIA R$ 36.610,00 186 CED 04 DO GUARA R$ 74.747 75
# 110 EC 45 DE CEILANDIA RS 47.460,00 187 CEE 01 DO GUARA R$ 38.565,00
# ll EC 46 DE CEILANDIA R$ 32.915,00 188 CEF 01 DO GUARA R$ 36.510,00
# 112 EC 47 DE CEILANDIA RS 35.215.00 189 CEF 02 DA ESTRUTURAL R$ 104.629,75
# . <a 190 CEF 02 DO GUARA R$ 47.782,75
# U3 EC 48 DE CEILANDIA R$ 41.005,00 191 CEF 03 DA ESTRUTURAL R$ 31,260.00
# 114 EC 50 DE CEILANDIA RS 49.812,75 192 CEF 04 DO GUARA RS 78.829.75
# 115 EC 52 DE CEILANDIA R$ 55.915,50 193 CEF 05 DO GUARA R$ 38.775,00
# 116 EC 55 DE CEILANDIA RS 44.381,75 195 OEE o bo ovaRe Re Sroes a
# 117 EC 56 DE CEILANDIA R$ 54.777,00 196 _ CEI 01 DA ESTRUTURAL R$ 27.805.00
# 118 EC 59 DE CEILANDIA R$_28.297,50 197 CEM 01 DO GUARA R$ 97.915,00
# 119 EC 61 DE CEILANDIA RS 46.685,00 198 CEP ARTICULADO DO GUARA - PROF TERESA ONDINA| R$ 56.199,00
# 120 EC 62 DE CEILANDIA RS 34.580,00 .
# = : 199 CIL_ DO GUARA RS 168.657,50
# Rl EC 64 DE CEILANDIA R$ 37.835,00 200 EC 01 DA VILA ESTRUTURAL RS 84.542,75
# 122 EC 65 DE CEILANDIA R$ 71.289,50 201 EC 01 DO GUARA R$ 17.320,00
# 123 EC 66 DE CEILANDIA RS 76.418,75 202 EC 02 DA ESTRUTURAL R$ 46.104,00
# = BE él DE CHANDA memo 3 rcp BMRA Re iasaie
# 125 EC CORREGO DAS CORUJAS R$ 6.622,00 505 EC 03 DO GUARA RE 23: 100,00
# 126 EC DO SETOR P NORTE R$ 56.883,75 206 | EC 05 DO GUARA RS 30.400,00
# 127 EC JIBOIA R$ 5.000,00 207 EC 06 DO GUARA R$ 30.640,00
# 128 EC JK DO SOL NASCENTE RS 62.400,00 208 EC 07 DO GUARA R$ 35.125,00
# 129 EC LAJES DA JIBOIA R$ 21.166,75 a Eee pe SV Re isons a
# 130 EP ANISIO TEIXEIRA R$ 208.477,50 211 Tl LUCIO COSTA RS 11.465 00
# 131 CRE GAMA R$ 190.000,00 212 CRE NUCLEO BANDEIRANTE RS 170.000,00
# 132 CAIC CARLOS CASTELLO BRANCO R$ 22.850,00 TF NS BLDG RDCHO PUNDOIT Re sone =
# 133 CED 06 DO GAMA R$ 76.355,50 215 CED 02 DO RIACHO FUNDO R$ 106.188,00
# 134 CED 07 DO GAMA R$_99.003,25 216 CED AGROURBANO IPE RIACHO FUNDO R$ 42.630,00
# 135 CED 08 DO GAMA R$ 65.135,00 217 CED _VARGEM BONITA R$ 32.119,00
# 136 CED CASA GRANDE R$ 33.904,50 218 CEF 01 DA CANDANGOLANDIA RS 30.711,00
# 137 CED ENGENHO DAS LAJES R$ 53.766,50 219 CEF 01 DO NUCLEO BANDEIRANTE RS 61.385,75
# 138 CED GESNER TEIXEIRA Re 31 800.00 220 CEF 01 DO RIACHO FUNDO II RS 160.360,75
# UY, 221 _ CEF 02 DO RIACHO FUNDO II RS 77.010,25
# 139 CEE 01 DO GAMA R$ 47.685,00 222 © CEF METROPOLITANA R$ 33.320,00
# 140 CEF 01 DO GAMA RS 55.155,00 223 CEF TELEBRASILIA RS 67.770,00
# 141 CEF 03 DO GAMA R$ 76.390,00 224 CEI 01 DO RIACHO FUNDO I R$ 20.665,00
# 2 225 CEI DA CANDANGOLANDIA R$ 17.575,00
# 142 CEF 04 DO GAMA R$ _64.352,25 226 CEI DO NUCLEO BANDEIRANTE R$ 25.345.00
# 143 CEF 05 DO GAMA R$ 52.727,75 227 CEI DO RIACHO FUNDO II R$ 40.940,00
# 144 CEF 08 DO GAMA RS 52.259,75 228 CEM 01 DO RIACHO FUNDO R$ 76.306,75
# 145 CEF 10 DO GAMA RS 56.735,00__ 35 «CEM URSO BRANCO Ry 7998000
# 146 CEF 1 DO GAMA R§_87.545,00 31 CIL DO NUCLEO BANDEIRANTE RS 31.625.00
# 147 CEF 15 DO GAMA R$ _64.285,00 232 CIL DO RIACHO FUNDO RS 35.310,00
# 148 CEF PONTE ALTA DO BAIXO RS 16.659,00 233 CIL DO RIACHO FUNDO II R$ 28.765,00
# 149 CEF PONTE ALTA NORTE R$ 20.992,00 234 EC 01 DA CANDANGOLANDIA R$ 22.660,00
# ; 235 EC 01 DO RIACHO FUNDO II RS _67.510,00
# Ry Chto DO cata i coor og 236 EC 02 DA CANDANGOLANDIA R$ 27.935,00
# 070, 237 EC 02 DO RIACHO FUNDO R$ 35.625,00
# 152 CEM 01 DO GAMA R$ _132.700,00 238 | EC 02 DO, RIACHO FUNDO II RS 40.740,00
# 153 CEM 02 DO GAMA RS 136.621,50 239 | EC 03 DO NUCLEO BANDEIRANTE RS 23.585,00
# 154 CEM 03 DO GAMA RS 98.404.75 240 EC 04 DO NUCLEO BANDEIRANTE RS 20.315,00
# ma 241 EC 05 DO NUCLEO BANDEIRANTE RS_15.705,00
# 155 | CEM INTEGRADO A EDUC PROFISSIONAL DO GAMA RS 52.270,00 549 EC AGROVILA TI RS 2099000
# 156 CIL DO GAMA R$ 239.937,50 243 EC IPE R$ 36.556,00
# 157 EC 01 DO GAMA R$ 37.695,00 244 EC KANEGAE R$ 8.179,75
# 158 EC 02 DO GAMA R$ 38.300,00 245 EC RIACHO FUNDO R$ 39.427,75
# ; 246 EC VERDE DO RIACHO FUNDO I R$ 41.420,00
# 19 EC 03 DO GAMA RS 30.905,00 247 TL01 DO RIACHO FUNDO II RS 28,780.00
# 160 EC 06 DO GAMA R$ _14.010,00 248 CRE PARANOA R$ 170.000,00
# 249 CAIC SANTA PAULINA R$ 91.093,25
# re Ee 06 we aaMa Re seis a 250 CED 01 DO ITAPOA RS _71.840.00
# 163 FC 10 DO GAMA RE 20040,00 251 CED DARCY RIBEIRO R$ 95.361,00
# 164 EC 12 DO GAMA RS 23,568.25 2S ED DO PAD-DF__ RS 91.456.00
# 165 EC 14 DO GAMA RS 22,935.00 253 _ CEF 01 DO PARANOA R$ 130.943,25
# 166 EC 15 DO GAMA R$ 25.960,00 254 | CEF 02 DO PARANOA R$ 111.348,00
# 167 EC 16 DO GAMA R$ 21.450.25 255 CEF 03 DO PARANOA R$ _110.656,50
# 168 EC 17 DO GAMA R$ 16.500,00 256 CEF 04 DO PARANOA R$ _43.867,25
# 169 EC 18 DO GAMA R$ 22.790,00 257 CEF BURITI VERMELHO RS 24.698,00
# 170 EC 19 DO GAMA R$ 19.795.00 258 CEF DOUTORA ZILDA ARNS RS 126.333,00
# Este documento pode ser verificado no endereco cletrénico —http:/Avww.in.gov.br/autenticidade.html, Documento assinado digitalmente conforme MP n° 2.200-2 de 24/08/2001, que institui a
# pelo cédigo 50102020020400006 Infracstrutura de Chaves Publicas Brasileira - ICP-Brasil.
